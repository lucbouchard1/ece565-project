# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w = np.linspace(-5, 5, 100)

for n in [10, 20, 50]:
    plt.plot(w, (1 + np.exp(w))**2 / (n*np.exp(w)), label="n = " + str(n))

plt.legend()
